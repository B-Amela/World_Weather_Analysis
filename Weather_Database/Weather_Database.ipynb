# %%
#Import dependencies
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

from citipy import citipy

# %%
## Retreaving nearest city

# %%
#Create a set of 2,000 random latitude and longitude combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)

# %%
coordinates = list(lat_lngs)

cities = []
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    if city not in cities:
        cities.append(city)

len(cities)
# Out:
# 770

# %%
#performing an API Call with the Opean Weather Map

# %%
#Import dependencies
import requests
from config import weather_api_key

url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
city_data = []

print("Beginning Data Retrieval     ")
print("-----------------------------")

record_count = 1
set_count = 1

for i, city in enumerate(cities):
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    
    city_url = url + "&q=" + city.replace(" ","+")
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    record_count += 1
    
    try:
        city_weather = requests.get(city_url).json()
        city_lat = city_weather['coord']['lat']
        city_lng = city_weather['coord']['lon']
        city_max_temp = city_weather['main']['temp_max']
        city_humidity = city_weather['main']['humidity']
        city_clouds = city_weather['clouds']['all']
        city_wind = city_weather['wind']['speed']
        city_country = city_weather['sys']['country']
        city_description = city_weather['weather'][0]['description']
        
        city_data.append({'City': city.title(),
                          'Country': city_country,
                          'Lat': city_lat,
                          'Lng': city_lng,
                          'Max Temp': city_max_temp,
                          'Humidity': city_humidity,
                          'Cloudiness': city_clouds,
                          'Wind Speed': city_wind,
                          'Current Description': city_description})
    except:
        print("City not found. Skipping...")
        pass

print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | busselton
# Processing Record 2 of Set 1 | broome
# Processing Record 3 of Set 1 | presidencia roque saenz pena
# Processing Record 4 of Set 1 | beira
# Processing Record 5 of Set 1 | punta arenas
# Processing Record 6 of Set 1 | avarua
# Processing Record 7 of Set 1 | ribeira grande
# Processing Record 8 of Set 1 | lensk
# Processing Record 9 of Set 1 | lavrentiya
# Processing Record 10 of Set 1 | jamestown
# Processing Record 11 of Set 1 | port lincoln
# Processing Record 12 of Set 1 | luchegorsk
# Processing Record 13 of Set 1 | kapaa
# Processing Record 14 of Set 1 | yellowknife
# Processing Record 15 of Set 1 | atuona
# Processing Record 16 of Set 1 | kandrian
# Processing Record 17 of Set 1 | zhigansk
# Processing Record 18 of Set 1 | acapulco
# Processing Record 19 of Set 1 | ushuaia
# Processing Record 20 of Set 1 | rikitea
# Processing Record 21 of Set 1 | cidreira
# Processing Record 22 of Set 1 | hithadhoo
# Processing Record 23 of Set 1 | faanui
# Processing Record 24 of Set 1 | esperance
# Processing Record 25 of Set 1 | souillac
# Processing Record 26 of Set 1 | port elizabeth
# Processing Record 27 of Set 1 | andenes
# Processing Record 28 of Set 1 | victoria
# Processing Record 29 of Set 1 | kysyl-syr
# Processing Record 30 of Set 1 | tuktoyaktuk
# Processing Record 31 of Set 1 | qaanaaq
# Processing Record 32 of Set 1 | albany
# Processing Record 33 of Set 1 | carnarvon
# Processing Record 34 of Set 1 | puerto ayora
# Processing Record 35 of Set 1 | georgetown
# Processing Record 36 of Set 1 | ekhabi
# Processing Record 37 of Set 1 | mogadishu
# Processing Record 38 of Set 1 | zaraza
# Processing Record 39 of Set 1 | sibolga
# Processing Record 40 of Set 1 | thompson
# Processing Record 41 of Set 1 | sitrah
# Processing Record 42 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 43 of Set 1 | hilo
# Processing Record 44 of Set 1 | pacifica
# Processing Record 45 of Set 1 | kodiak
# Processing Record 46 of Set 1 | vila
# Processing Record 47 of Set 1 | ust-maya
# Processing Record 48 of Set 1 | hermanus
# Processing Record 49 of Set 1 | darhan
# Processing Record 50 of Set 1 | jvari
# Processing Record 1 of Set 2 | bluff
# Processing Record 2 of Set 2 | vestmannaeyjar
# Processing Record 3 of Set 2 | kokubu
# Processing Record 4 of Set 2 | castro
# Processing Record 5 of Set 2 | padang
# Processing Record 6 of Set 2 | kukmor
# Processing Record 7 of Set 2 | melfort
# Processing Record 8 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 9 of Set 2 | nome
# Processing Record 10 of Set 2 | sitka
# Processing Record 11 of Set 2 | santa rosa de cabal
# Processing Record 12 of Set 2 | east london
# Processing Record 13 of Set 2 | butaritari
# Processing Record 14 of Set 2 | iqaluit
# Processing Record 15 of Set 2 | sola
# Processing Record 16 of Set 2 | khatanga
# Processing Record 17 of Set 2 | bako
# Processing Record 18 of Set 2 | ponta do sol
# Processing Record 19 of Set 2 | saint-philippe
# Processing Record 20 of Set 2 | jose de freitas
# Processing Record 21 of Set 2 | tinskoy
# Processing Record 22 of Set 2 | buenos aires
# Processing Record 23 of Set 2 | guntakal
# Processing Record 24 of Set 2 | alofi
# Processing Record 25 of Set 2 | barrow
# Processing Record 26 of Set 2 | reading
# Processing Record 27 of Set 2 | mabaruma
# Processing Record 28 of Set 2 | torbay
# Processing Record 29 of Set 2 | cape town
# Processing Record 30 of Set 2 | podyuga
# Processing Record 31 of Set 2 | san quintin
# Processing Record 32 of Set 2 | kaduqli
# Processing Record 33 of Set 2 | maniitsoq
# Processing Record 34 of Set 2 | port alfred
# Processing Record 35 of Set 2 | tiksi
# Processing Record 36 of Set 2 | durusu
# Processing Record 37 of Set 2 | saint-leu
# Processing Record 38 of Set 2 | beyneu
# Processing Record 39 of Set 2 | vila velha
# Processing Record 40 of Set 2 | olafsvik
# Processing Record 41 of Set 2 | upernavik
# Processing Record 42 of Set 2 | puerto escondido
# Processing Record 43 of Set 2 | saskylakh
# Processing Record 44 of Set 2 | tuggurt
# City not found. Skipping...
# Processing Record 45 of Set 2 | glenwood springs
# Processing Record 46 of Set 2 | luau
# Processing Record 47 of Set 2 | boa vista
# Processing Record 48 of Set 2 | nemuro
# Processing Record 49 of Set 2 | griffin
# Processing Record 50 of Set 2 | stromness
# Processing Record 1 of Set 3 | qandala
# Processing Record 2 of Set 3 | nikolskoye
# Processing Record 3 of Set 3 | nanortalik
# Processing Record 4 of Set 3 | bambous virieux
# Processing Record 5 of Set 3 | constitucion
# Processing Record 6 of Set 3 | aurillac
# Processing Record 7 of Set 3 | ulaanbaatar
# Processing Record 8 of Set 3 | attawapiskat
# City not found. Skipping...
# Processing Record 9 of Set 3 | ergani
# Processing Record 10 of Set 3 | penzance
# Processing Record 11 of Set 3 | quatre cocos
# Processing Record 12 of Set 3 | jiehu
# Processing Record 13 of Set 3 | nizhneyansk
# City not found. Skipping...
# Processing Record 14 of Set 3 | dikson
# Processing Record 15 of Set 3 | yarmouth
# Processing Record 16 of Set 3 | zyryanka
# Processing Record 17 of Set 3 | grand gaube
# Processing Record 18 of Set 3 | suntar
# Processing Record 19 of Set 3 | vila franca do campo
# Processing Record 20 of Set 3 | airai
# Processing Record 21 of Set 3 | tiznit
# Processing Record 22 of Set 3 | coquimbo
# Processing Record 23 of Set 3 | estelle
# Processing Record 24 of Set 3 | nyurba
# Processing Record 25 of Set 3 | cayenne
# Processing Record 26 of Set 3 | anton lizardo
# Processing Record 27 of Set 3 | komsomolskiy
# Processing Record 28 of Set 3 | adamantina
# Processing Record 29 of Set 3 | mahebourg
# Processing Record 30 of Set 3 | lufilufi
# Processing Record 31 of Set 3 | ariquemes
# Processing Record 32 of Set 3 | klaksvik
# Processing Record 33 of Set 3 | yalta
# Processing Record 34 of Set 3 | nelson bay
# Processing Record 35 of Set 3 | vallenar
# Processing Record 36 of Set 3 | hobart
# Processing Record 37 of Set 3 | arraial do cabo
# Processing Record 38 of Set 3 | havre-saint-pierre
# Processing Record 39 of Set 3 | burnie
# Processing Record 40 of Set 3 | vrangel
# Processing Record 41 of Set 3 | buon me thuot
# City not found. Skipping...
# Processing Record 42 of Set 3 | ridgecrest
# Processing Record 43 of Set 3 | bredasdorp
# Processing Record 44 of Set 3 | cockburn town
# Processing Record 45 of Set 3 | carauari
# Processing Record 46 of Set 3 | kavieng
# Processing Record 47 of Set 3 | khonuu
# City not found. Skipping...
# Processing Record 48 of Set 3 | bay roberts
# Processing Record 49 of Set 3 | pisco
# Processing Record 50 of Set 3 | borodino
# Processing Record 1 of Set 4 | rielasingen-worblingen
# Processing Record 2 of Set 4 | longyearbyen
# Processing Record 3 of Set 4 | petropavlovsk-kamchatskiy
# Processing Record 4 of Set 4 | laguna
# Processing Record 5 of Set 4 | carutapera
# Processing Record 6 of Set 4 | warwick
# Processing Record 7 of Set 4 | pevek
# Processing Record 8 of Set 4 | leshukonskoye
# Processing Record 9 of Set 4 | berlevag
# Processing Record 10 of Set 4 | crab hill
# City not found. Skipping...
# Processing Record 11 of Set 4 | mount isa
# Processing Record 12 of Set 4 | barentsburg
# City not found. Skipping...
# Processing Record 13 of Set 4 | baghmara
# Processing Record 14 of Set 4 | punta de bombon
# Processing Record 15 of Set 4 | urdzhar
# City not found. Skipping...
# Processing Record 16 of Set 4 | saint-raymond
# Processing Record 17 of Set 4 | plastun
# Processing Record 18 of Set 4 | pascagoula
# Processing Record 19 of Set 4 | tasiilaq
# Processing Record 20 of Set 4 | huixtla
# Processing Record 21 of Set 4 | bilibino
# Processing Record 22 of Set 4 | wajima
# Processing Record 23 of Set 4 | ocos
# Processing Record 24 of Set 4 | nabire
# Processing Record 25 of Set 4 | nerchinskiy zavod
# Processing Record 26 of Set 4 | mataura
# Processing Record 27 of Set 4 | solnechnyy
# Processing Record 28 of Set 4 | arkhipo-osipovka
# Processing Record 29 of Set 4 | lima
# Processing Record 30 of Set 4 | sataua
# City not found. Skipping...
# Processing Record 31 of Set 4 | kembe
# Processing Record 32 of Set 4 | katsuura
# Processing Record 33 of Set 4 | yatou
# Processing Record 34 of Set 4 | new norfolk
# Processing Record 35 of Set 4 | salalah
# Processing Record 36 of Set 4 | yumen
# Processing Record 37 of Set 4 | kupang
# Processing Record 38 of Set 4 | mys shmidta
# City not found. Skipping...
# Processing Record 39 of Set 4 | fare
# Processing Record 40 of Set 4 | barra patuca
# Processing Record 41 of Set 4 | ust-ishim
# Processing Record 42 of Set 4 | tura
# Processing Record 43 of Set 4 | saint anthony
# Processing Record 44 of Set 4 | deputatskiy
# Processing Record 45 of Set 4 | provideniya
# Processing Record 46 of Set 4 | kruisfontein
# Processing Record 47 of Set 4 | ashqelon
# Processing Record 48 of Set 4 | tamandare
# Processing Record 49 of Set 4 | leiyang
# Processing Record 50 of Set 4 | bethel
# Processing Record 1 of Set 5 | te anau
# Processing Record 2 of Set 5 | acari
# Processing Record 3 of Set 5 | boden
# Processing Record 4 of Set 5 | arman
# Processing Record 5 of Set 5 | lasa
# Processing Record 6 of Set 5 | amderma
# City not found. Skipping...
# Processing Record 7 of Set 5 | san felipe
# Processing Record 8 of Set 5 | severo-kurilsk
# Processing Record 9 of Set 5 | nishihara
# Processing Record 10 of Set 5 | grand river south east
# City not found. Skipping...
# Processing Record 11 of Set 5 | vaini
# Processing Record 12 of Set 5 | manhattan
# Processing Record 13 of Set 5 | suchindram
# Processing Record 14 of Set 5 | soyo
# Processing Record 15 of Set 5 | biryusinsk
# Processing Record 16 of Set 5 | lida
# Processing Record 17 of Set 5 | hirara
# Processing Record 18 of Set 5 | ust-karsk
# Processing Record 19 of Set 5 | bowen
# Processing Record 20 of Set 5 | flinders
# Processing Record 21 of Set 5 | karratha
# Processing Record 22 of Set 5 | naze
# Processing Record 23 of Set 5 | santa maria
# Processing Record 24 of Set 5 | cherskiy
# Processing Record 25 of Set 5 | saint george
# Processing Record 26 of Set 5 | porto velho
# Processing Record 27 of Set 5 | guerrero negro
# Processing Record 28 of Set 5 | sentyabrskiy
# City not found. Skipping...
# Processing Record 29 of Set 5 | mendeleyevo
# Processing Record 30 of Set 5 | mount gambier
# Processing Record 31 of Set 5 | khani
# Processing Record 32 of Set 5 | malakal
# Processing Record 33 of Set 5 | ambilobe
# Processing Record 34 of Set 5 | saint-joseph
# Processing Record 35 of Set 5 | dabakala
# Processing Record 36 of Set 5 | kyshtovka
# Processing Record 37 of Set 5 | toungoo
# City not found. Skipping...
# Processing Record 38 of Set 5 | saurimo
# Processing Record 39 of Set 5 | campestre
# Processing Record 40 of Set 5 | bonfim
# Processing Record 41 of Set 5 | jalu
# Processing Record 42 of Set 5 | vanimo
# Processing Record 43 of Set 5 | samfya
# Processing Record 44 of Set 5 | bengkulu
# Processing Record 45 of Set 5 | carmarthen
# Processing Record 46 of Set 5 | dolbeau
# City not found. Skipping...
# Processing Record 47 of Set 5 | pompeia
# Processing Record 48 of Set 5 | plettenberg bay
# Processing Record 49 of Set 5 | vardo
# Processing Record 50 of Set 5 | dingle
# Processing Record 1 of Set 6 | meulaboh
# Processing Record 2 of Set 6 | gorontalo
# Processing Record 3 of Set 6 | churumuco
# City not found. Skipping...
# Processing Record 4 of Set 6 | malwan
# City not found. Skipping...
# Processing Record 5 of Set 6 | ledyard
# Processing Record 6 of Set 6 | lebu
# Processing Record 7 of Set 6 | port-gentil
# Processing Record 8 of Set 6 | mar del plata
# Processing Record 9 of Set 6 | roanoke rapids
# Processing Record 10 of Set 6 | kaitangata
# Processing Record 11 of Set 6 | tunduma
# Processing Record 12 of Set 6 | nurota
# Processing Record 13 of Set 6 | ulcinj
# Processing Record 14 of Set 6 | olenino
# Processing Record 15 of Set 6 | axim
# Processing Record 16 of Set 6 | maragogi
# Processing Record 17 of Set 6 | flagstaff
# Processing Record 18 of Set 6 | buraydah
# Processing Record 19 of Set 6 | west fargo
# Processing Record 20 of Set 6 | tautira
# Processing Record 21 of Set 6 | mwene-ditu
# Processing Record 22 of Set 6 | fukue
# Processing Record 23 of Set 6 | banda aceh
# Processing Record 24 of Set 6 | santa rita
# Processing Record 25 of Set 6 | kavaratti
# Processing Record 26 of Set 6 | chuy
# Processing Record 27 of Set 6 | krasnovishersk
# Processing Record 28 of Set 6 | lardos
# Processing Record 29 of Set 6 | nguiu
# City not found. Skipping...
# Processing Record 30 of Set 6 | hammerfest
# Processing Record 31 of Set 6 | inhambane
# Processing Record 32 of Set 6 | tanshui
# City not found. Skipping...
# Processing Record 33 of Set 6 | kununurra
# Processing Record 34 of Set 6 | geraldton
# Processing Record 35 of Set 6 | rantoul
# Processing Record 36 of Set 6 | codrington
# Processing Record 37 of Set 6 | high level
# Processing Record 38 of Set 6 | mecca
# Processing Record 39 of Set 6 | lagoa
# Processing Record 40 of Set 6 | ancud
# Processing Record 41 of Set 6 | otofuke
# Processing Record 42 of Set 6 | severobaykalsk
# Processing Record 43 of Set 6 | fallon
# Processing Record 44 of Set 6 | isla vista
# Processing Record 45 of Set 6 | puerto varas
# Processing Record 46 of Set 6 | sungai padi
# Processing Record 47 of Set 6 | coihaique
# Processing Record 48 of Set 6 | narsimhapur
# Processing Record 49 of Set 6 | mzimba
# Processing Record 50 of Set 6 | beroroha
# Processing Record 1 of Set 7 | nioro
# Processing Record 2 of Set 7 | nakama
# Processing Record 3 of Set 7 | oksfjord
# Processing Record 4 of Set 7 | margate
# Processing Record 5 of Set 7 | fortuna
# Processing Record 6 of Set 7 | puerto penasco
# Processing Record 7 of Set 7 | tondano
# Processing Record 8 of Set 7 | fort nelson
# Processing Record 9 of Set 7 | tukrah
# Processing Record 10 of Set 7 | bereda
# Processing Record 11 of Set 7 | adre
# Processing Record 12 of Set 7 | nigran
# Processing Record 13 of Set 7 | misratah
# Processing Record 14 of Set 7 | sinjah
# City not found. Skipping...
# Processing Record 15 of Set 7 | grindavik
# Processing Record 16 of Set 7 | pacific grove
# Processing Record 17 of Set 7 | pangody
# Processing Record 18 of Set 7 | yei
# Processing Record 19 of Set 7 | belushya guba
# City not found. Skipping...
# Processing Record 20 of Set 7 | evensk
# Processing Record 21 of Set 7 | ban nahin
# Processing Record 22 of Set 7 | demyansk
# Processing Record 23 of Set 7 | cortez
# Processing Record 24 of Set 7 | muzhi
# Processing Record 25 of Set 7 | cairns
# Processing Record 26 of Set 7 | tsiroanomandidy
# Processing Record 27 of Set 7 | pyaozerskiy
# Processing Record 28 of Set 7 | luderitz
# Processing Record 29 of Set 7 | saldanha
# Processing Record 30 of Set 7 | chokurdakh
# Processing Record 31 of Set 7 | troitskoye
# Processing Record 32 of Set 7 | contamana
# Processing Record 33 of Set 7 | glen carbon
# Processing Record 34 of Set 7 | elko
# Processing Record 35 of Set 7 | wilmington island
# Processing Record 36 of Set 7 | marawi
# Processing Record 37 of Set 7 | rabo de peixe
# Processing Record 38 of Set 7 | ho chi minh city
# Processing Record 39 of Set 7 | altay
# Processing Record 40 of Set 7 | saleaula
# City not found. Skipping...
# Processing Record 41 of Set 7 | baiyin
# Processing Record 42 of Set 7 | cedar city
# Processing Record 43 of Set 7 | iskateley
# Processing Record 44 of Set 7 | port moresby
# Processing Record 45 of Set 7 | labuhan
# Processing Record 46 of Set 7 | richards bay
# Processing Record 47 of Set 7 | balotra
# Processing Record 48 of Set 7 | harper
# Processing Record 49 of Set 7 | novikovo
# Processing Record 50 of Set 7 | verkhoyansk
# Processing Record 1 of Set 8 | jibuti
# Processing Record 2 of Set 8 | duns
# Processing Record 3 of Set 8 | narsaq
# Processing Record 4 of Set 8 | xining
# Processing Record 5 of Set 8 | ketchikan
# Processing Record 6 of Set 8 | petropavlovskoye
# Processing Record 7 of Set 8 | twentynine palms
# Processing Record 8 of Set 8 | hualmay
# Processing Record 9 of Set 8 | rolante
# Processing Record 10 of Set 8 | mumford
# Processing Record 11 of Set 8 | huarmey
# Processing Record 12 of Set 8 | do rud
# City not found. Skipping...
# Processing Record 13 of Set 8 | balimo
# City not found. Skipping...
# Processing Record 14 of Set 8 | asfi
# Processing Record 15 of Set 8 | saryozek
# Processing Record 16 of Set 8 | tabou
# Processing Record 17 of Set 8 | clyde river
# Processing Record 18 of Set 8 | sorland
# Processing Record 19 of Set 8 | bure
# Processing Record 20 of Set 8 | chara
# Processing Record 21 of Set 8 | taoudenni
# Processing Record 22 of Set 8 | skovorodino
# Processing Record 23 of Set 8 | konnur
# Processing Record 24 of Set 8 | wilhelmsburg
# Processing Record 25 of Set 8 | seoul
# Processing Record 26 of Set 8 | ilulissat
# Processing Record 27 of Set 8 | ostrovnoy
# Processing Record 28 of Set 8 | arrecife
# Processing Record 29 of Set 8 | tuatapere
# Processing Record 30 of Set 8 | shelburne
# Processing Record 31 of Set 8 | rawson
# Processing Record 32 of Set 8 | new glasgow
# Processing Record 33 of Set 8 | otane
# Processing Record 34 of Set 8 | walvis bay
# Processing Record 35 of Set 8 | wanaka
# Processing Record 36 of Set 8 | palabuhanratu
# City not found. Skipping...
# Processing Record 37 of Set 8 | caravelas
# Processing Record 38 of Set 8 | hasaki
# Processing Record 39 of Set 8 | norman wells
# Processing Record 40 of Set 8 | natal
# Processing Record 41 of Set 8 | aquiraz
# Processing Record 42 of Set 8 | floro
# Processing Record 43 of Set 8 | pitimbu
# Processing Record 44 of Set 8 | dawei
# Processing Record 45 of Set 8 | fairbanks
# Processing Record 46 of Set 8 | mawlaik
# Processing Record 47 of Set 8 | barda
# Processing Record 48 of Set 8 | champerico
# Processing Record 49 of Set 8 | tongliao
# Processing Record 50 of Set 8 | egvekinot
# Processing Record 1 of Set 9 | phulpur
# Processing Record 2 of Set 9 | mizpe ramon
# City not found. Skipping...
# Processing Record 3 of Set 9 | alamos
# Processing Record 4 of Set 9 | yunjinghong
# City not found. Skipping...
# Processing Record 5 of Set 9 | sao joao da barra
# Processing Record 6 of Set 9 | basyanovskiy
# City not found. Skipping...
# Processing Record 7 of Set 9 | khed brahma
# Processing Record 8 of Set 9 | sebring
# Processing Record 9 of Set 9 | koslan
# Processing Record 10 of Set 9 | paita
# Processing Record 11 of Set 9 | turan
# Processing Record 12 of Set 9 | valparaiso
# Processing Record 13 of Set 9 | haibowan
# City not found. Skipping...
# Processing Record 14 of Set 9 | lyuban
# Processing Record 15 of Set 9 | srednekolymsk
# Processing Record 16 of Set 9 | henties bay
# Processing Record 17 of Set 9 | mergui
# City not found. Skipping...
# Processing Record 18 of Set 9 | vaitupu
# City not found. Skipping...
# Processing Record 19 of Set 9 | cabo san lucas
# Processing Record 20 of Set 9 | abu samrah
# Processing Record 21 of Set 9 | san jose
# Processing Record 22 of Set 9 | shambu
# Processing Record 23 of Set 9 | hofn
# Processing Record 24 of Set 9 | saint-pierre
# Processing Record 25 of Set 9 | kungurtug
# Processing Record 26 of Set 9 | xinxiang
# Processing Record 27 of Set 9 | brigantine
# Processing Record 28 of Set 9 | megion
# Processing Record 29 of Set 9 | riyadh
# Processing Record 30 of Set 9 | roebourne
# Processing Record 31 of Set 9 | louisbourg
# City not found. Skipping...
# Processing Record 32 of Set 9 | knysna
# Processing Record 33 of Set 9 | thap than
# Processing Record 34 of Set 9 | jumla
# Processing Record 35 of Set 9 | torata
# Processing Record 36 of Set 9 | voh
# Processing Record 37 of Set 9 | gampaha
# Processing Record 38 of Set 9 | bairiki
# Processing Record 39 of Set 9 | hambantota
# Processing Record 40 of Set 9 | aripuana
# Processing Record 41 of Set 9 | batemans bay
# Processing Record 42 of Set 9 | hamilton
# Processing Record 43 of Set 9 | bandarbeyla
# Processing Record 44 of Set 9 | launceston
# Processing Record 45 of Set 9 | adrar
# Processing Record 46 of Set 9 | ballina
# Processing Record 47 of Set 9 | taywarah
# Processing Record 48 of Set 9 | bethlehem
# Processing Record 49 of Set 9 | bahia blanca
# Processing Record 50 of Set 9 | celestun
# Processing Record 1 of Set 10 | sao filipe
# Processing Record 2 of Set 10 | yar-sale
# Processing Record 3 of Set 10 | okhotsk
# Processing Record 4 of Set 10 | turukhansk
# Processing Record 5 of Set 10 | sembe
# Processing Record 6 of Set 10 | london
# Processing Record 7 of Set 10 | zhezkazgan
# Processing Record 8 of Set 10 | lolua
# City not found. Skipping...
# Processing Record 9 of Set 10 | inverell
# Processing Record 10 of Set 10 | tsihombe
# City not found. Skipping...
# Processing Record 11 of Set 10 | frunze
# Processing Record 12 of Set 10 | codajas
# Processing Record 13 of Set 10 | ulety
# Processing Record 14 of Set 10 | cam ranh
# Processing Record 15 of Set 10 | juegang
# Processing Record 16 of Set 10 | talcahuano
# Processing Record 17 of Set 10 | svetlogorsk
# Processing Record 18 of Set 10 | erzin
# Processing Record 19 of Set 10 | ajdabiya
# Processing Record 20 of Set 10 | dezful
# Processing Record 21 of Set 10 | batagay
# Processing Record 22 of Set 10 | kailua
# Processing Record 23 of Set 10 | warqla
# City not found. Skipping...
# Processing Record 24 of Set 10 | roald
# Processing Record 25 of Set 10 | panuco
# Processing Record 26 of Set 10 | sligo
# Processing Record 27 of Set 10 | kirakira
# Processing Record 28 of Set 10 | am timan
# Processing Record 29 of Set 10 | yaring
# Processing Record 30 of Set 10 | sovetskiy
# Processing Record 31 of Set 10 | sumenep
# Processing Record 32 of Set 10 | kosh-agach
# Processing Record 33 of Set 10 | diego de almagro
# Processing Record 34 of Set 10 | grao mogol
# Processing Record 35 of Set 10 | ada
# Processing Record 36 of Set 10 | zemio
# Processing Record 37 of Set 10 | springbok
# Processing Record 38 of Set 10 | williams lake
# Processing Record 39 of Set 10 | verkhnevilyuysk
# Processing Record 40 of Set 10 | faya
# Processing Record 41 of Set 10 | nampula
# Processing Record 42 of Set 10 | wembley
# Processing Record 43 of Set 10 | tshane
# Processing Record 44 of Set 10 | dunedin
# Processing Record 45 of Set 10 | tambul
# City not found. Skipping...
# Processing Record 46 of Set 10 | swakopmund
# Processing Record 47 of Set 10 | trincomalee
# Processing Record 48 of Set 10 | mount darwin
# Processing Record 49 of Set 10 | tilichiki
# Processing Record 50 of Set 10 | los alamos
# Processing Record 1 of Set 11 | anadyr
# Processing Record 2 of Set 11 | gorazde
# Processing Record 3 of Set 11 | ileza
# Processing Record 4 of Set 11 | touros
# Processing Record 5 of Set 11 | chardara
# Processing Record 6 of Set 11 | paramonga
# Processing Record 7 of Set 11 | sao felix do xingu
# Processing Record 8 of Set 11 | mendahara
# City not found. Skipping...
# Processing Record 9 of Set 11 | san patricio
# Processing Record 10 of Set 11 | peleduy
# Processing Record 11 of Set 11 | nhulunbuy
# Processing Record 12 of Set 11 | port blair
# Processing Record 13 of Set 11 | ponta delgada
# Processing Record 14 of Set 11 | makakilo city
# Processing Record 15 of Set 11 | labuan
# Processing Record 16 of Set 11 | sisimiut
# Processing Record 17 of Set 11 | oranjemund
# Processing Record 18 of Set 11 | tessalit
# Processing Record 19 of Set 11 | north bend
# Processing Record 20 of Set 11 | thinadhoo
# Processing Record 21 of Set 11 | bima
# Processing Record 22 of Set 11 | lundazi
# Processing Record 23 of Set 11 | port hardy
# Processing Record 24 of Set 11 | saint-ambroise
# Processing Record 25 of Set 11 | phan thiet
# Processing Record 26 of Set 11 | husavik
# Processing Record 27 of Set 11 | bad freienwalde
# Processing Record 28 of Set 11 | chicama
# Processing Record 29 of Set 11 | hervey bay
# Processing Record 30 of Set 11 | orzinuovi
# Processing Record 31 of Set 11 | kurchatov
# Processing Record 32 of Set 11 | san cristobal
# Processing Record 33 of Set 11 | chapada dos guimaraes
# Processing Record 34 of Set 11 | ixtapa
# Processing Record 35 of Set 11 | kulu
# Processing Record 36 of Set 11 | makaryev
# Processing Record 37 of Set 11 | beringovskiy
# Processing Record 38 of Set 11 | vizinga
# Processing Record 39 of Set 11 | grand centre
# City not found. Skipping...
# Processing Record 40 of Set 11 | puteyets
# Processing Record 41 of Set 11 | porto-vecchio
# Processing Record 42 of Set 11 | chapais
# Processing Record 43 of Set 11 | nyanguge
# Processing Record 44 of Set 11 | kingston
# Processing Record 45 of Set 11 | asau
# Processing Record 46 of Set 11 | ust-nera
# Processing Record 47 of Set 11 | baracoa
# Processing Record 48 of Set 11 | vyartsilya
# Processing Record 49 of Set 11 | wukari
# Processing Record 50 of Set 11 | gdov
# Processing Record 1 of Set 12 | nalut
# Processing Record 2 of Set 12 | ormara
# Processing Record 3 of Set 12 | zonguldak
# Processing Record 4 of Set 12 | madina
# Processing Record 5 of Set 12 | assare
# Processing Record 6 of Set 12 | kirando
# Processing Record 7 of Set 12 | hillsborough
# Processing Record 8 of Set 12 | ailigandi
# Processing Record 9 of Set 12 | praia da vitoria
# Processing Record 10 of Set 12 | iberia
# Processing Record 11 of Set 12 | tombouctou
# Processing Record 12 of Set 12 | sao jose da coroa grande
# Processing Record 13 of Set 12 | yantongshan
# Processing Record 14 of Set 12 | musoma
# Processing Record 15 of Set 12 | wagar
# Processing Record 16 of Set 12 | solovetskiy
# City not found. Skipping...
# Processing Record 17 of Set 12 | tadine
# Processing Record 18 of Set 12 | nuuk
# Processing Record 19 of Set 12 | christchurch
# Processing Record 20 of Set 12 | elbistan
# Processing Record 21 of Set 12 | nouadhibou
# Processing Record 22 of Set 12 | hargeysa
# Processing Record 23 of Set 12 | gat
# Processing Record 24 of Set 12 | oktyabrskiy
# Processing Record 25 of Set 12 | melo
# Processing Record 26 of Set 12 | bargal
# City not found. Skipping...
# Processing Record 27 of Set 12 | kurilsk
# Processing Record 28 of Set 12 | machico
# Processing Record 29 of Set 12 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 30 of Set 12 | boo
# Processing Record 31 of Set 12 | tecpan
# Processing Record 32 of Set 12 | preobrazheniye
# Processing Record 33 of Set 12 | sahrak
# City not found. Skipping...
# Processing Record 34 of Set 12 | iracoubo
# Processing Record 35 of Set 12 | myrtle beach
# Processing Record 36 of Set 12 | vostok
# Processing Record 37 of Set 12 | sumbawa
# City not found. Skipping...
# Processing Record 38 of Set 12 | sfantu gheorghe
# Processing Record 39 of Set 12 | krutikha
# Processing Record 40 of Set 12 | kilemary
# Processing Record 41 of Set 12 | takoradi
# Processing Record 42 of Set 12 | horki
# Processing Record 43 of Set 12 | vitimskiy
# City not found. Skipping...
# Processing Record 44 of Set 12 | wamba
# Processing Record 45 of Set 12 | zyryanskoye
# Processing Record 46 of Set 12 | feijo
# Processing Record 47 of Set 12 | port keats
# Processing Record 48 of Set 12 | bubaque
# Processing Record 49 of Set 12 | shchelyayur
# City not found. Skipping...
# Processing Record 50 of Set 12 | znamenskoye
# Processing Record 1 of Set 13 | lakes entrance
# Processing Record 2 of Set 13 | caucaia
# Processing Record 3 of Set 13 | kichera
# Processing Record 4 of Set 13 | kurumkan
# Processing Record 5 of Set 13 | letpadan
# Processing Record 6 of Set 13 | saryshagan
# City not found. Skipping...
# Processing Record 7 of Set 13 | moron
# Processing Record 8 of Set 13 | wajir
# Processing Record 9 of Set 13 | auki
# Processing Record 10 of Set 13 | sorvag
# City not found. Skipping...
# Processing Record 11 of Set 13 | berdigestyakh
# Processing Record 12 of Set 13 | antalaha
# Processing Record 13 of Set 13 | muisne
# Processing Record 14 of Set 13 | fevik
# Processing Record 15 of Set 13 | ishii
# Processing Record 16 of Set 13 | santiago
# Processing Record 17 of Set 13 | payyannur
# Processing Record 18 of Set 13 | livingstone
# Processing Record 19 of Set 13 | maarianhamina
# Processing Record 20 of Set 13 | vagur
# Processing Record 21 of Set 13 | maykor
# Processing Record 22 of Set 13 | gamba
# Processing Record 23 of Set 13 | muros
# Processing Record 24 of Set 13 | bosaso
# Processing Record 25 of Set 13 | albemarle
# Processing Record 26 of Set 13 | sinnamary
# Processing Record 27 of Set 13 | chandler
# Processing Record 28 of Set 13 | bolungarvik
# City not found. Skipping...
# Processing Record 29 of Set 13 | nyimba
# Processing Record 30 of Set 13 | oktyabrskoye
# Processing Record 31 of Set 13 | joshimath
# Processing Record 32 of Set 13 | pizarro
# Processing Record 33 of Set 13 | porto novo
# Processing Record 34 of Set 13 | borger
# Processing Record 35 of Set 13 | tosya
# Processing Record 36 of Set 13 | tlacolula
# Processing Record 37 of Set 13 | la ronge
# Processing Record 38 of Set 13 | tommot
# Processing Record 39 of Set 13 | minas
# Processing Record 40 of Set 13 | russell
# Processing Record 41 of Set 13 | arlit
# Processing Record 42 of Set 13 | kharp
# Processing Record 43 of Set 13 | norsup
# Processing Record 44 of Set 13 | kearney
# Processing Record 45 of Set 13 | aklavik
# Processing Record 46 of Set 13 | merauke
# Processing Record 47 of Set 13 | iquitos
# Processing Record 48 of Set 13 | nizhniy odes
# Processing Record 49 of Set 13 | hobyo
# Processing Record 50 of Set 13 | udachnyy
# Processing Record 1 of Set 14 | port pirie
# Processing Record 2 of Set 14 | capao bonito
# Processing Record 3 of Set 14 | griffith
# Processing Record 4 of Set 14 | puerto armuelles
# Processing Record 5 of Set 14 | ellisras
# Processing Record 6 of Set 14 | pedernales
# Processing Record 7 of Set 14 | greeley
# Processing Record 8 of Set 14 | gillette
# Processing Record 9 of Set 14 | galesong
# Processing Record 10 of Set 14 | belmonte
# Processing Record 11 of Set 14 | mersing
# Processing Record 12 of Set 14 | itoman
# Processing Record 13 of Set 14 | le port
# Processing Record 14 of Set 14 | eureka
# Processing Record 15 of Set 14 | amazar
# Processing Record 16 of Set 14 | keuruu
# Processing Record 17 of Set 14 | nortelandia
# Processing Record 18 of Set 14 | igarka
# Processing Record 19 of Set 14 | rio gallegos
# Processing Record 20 of Set 14 | ejura
# Processing Record 21 of Set 14 | orlik
# Processing Record 22 of Set 14 | altamira
# Processing Record 23 of Set 14 | kuito
# Processing Record 24 of Set 14 | barahona
# Processing Record 25 of Set 14 | meyungs
# City not found. Skipping...
# Processing Record 26 of Set 14 | eregli
# Processing Record 27 of Set 14 | pilar
# Processing Record 28 of Set 14 | marquette
# Processing Record 29 of Set 14 | ajaccio
# Processing Record 30 of Set 14 | cascina
# Processing Record 31 of Set 14 | nikolayevka
# Processing Record 32 of Set 14 | santa cruz del sur
# Processing Record 33 of Set 14 | parfino
# Processing Record 34 of Set 14 | corredor
# Processing Record 35 of Set 14 | malaga
# Processing Record 36 of Set 14 | avera
# Processing Record 37 of Set 14 | ahipara
# Processing Record 38 of Set 14 | kajaani
# Processing Record 39 of Set 14 | verkhnyaya inta
# Processing Record 40 of Set 14 | kulashi
# Processing Record 41 of Set 14 | carmen
# Processing Record 42 of Set 14 | doha
# Processing Record 43 of Set 14 | kambove
# Processing Record 44 of Set 14 | caraballeda
# Processing Record 45 of Set 14 | chifeng
# Processing Record 46 of Set 14 | umm lajj
# Processing Record 47 of Set 14 | satitoa
# City not found. Skipping...
# Processing Record 48 of Set 14 | dolinsk
# Processing Record 49 of Set 14 | barawe
# City not found. Skipping...
# Processing Record 50 of Set 14 | noyabrsk
# Processing Record 1 of Set 15 | aranda de duero
# Processing Record 2 of Set 15 | sandy bay
# Processing Record 3 of Set 15 | dakar
# Processing Record 4 of Set 15 | kushima
# Processing Record 5 of Set 15 | lompoc
# Processing Record 6 of Set 15 | puri
# Processing Record 7 of Set 15 | okato
# Processing Record 8 of Set 15 | necochea
# Processing Record 9 of Set 15 | la rioja
# Processing Record 10 of Set 15 | sao bento
# Processing Record 11 of Set 15 | haicheng
# Processing Record 12 of Set 15 | dharchula
# Processing Record 13 of Set 15 | campoverde
# Processing Record 14 of Set 15 | kyra
# Processing Record 15 of Set 15 | kieta
# Processing Record 16 of Set 15 | miranorte
# City not found. Skipping...
# Processing Record 17 of Set 15 | sinegorye
# Processing Record 18 of Set 15 | belaya gora
# Processing Record 19 of Set 15 | brae
# Processing Record 20 of Set 15 | hami
# Processing Record 21 of Set 15 | alakurtti
# Processing Record 22 of Set 15 | marzuq
# Processing Record 23 of Set 15 | half moon bay
# Processing Record 24 of Set 15 | nador
# Processing Record 25 of Set 15 | sand springs
# Processing Record 26 of Set 15 | acuna
# City not found. Skipping...
# Processing Record 27 of Set 15 | sheridan
# Processing Record 28 of Set 15 | uyemskiy
# Processing Record 29 of Set 15 | medina del campo
# Processing Record 30 of Set 15 | mangrol
# Processing Record 31 of Set 15 | la palma
# Processing Record 32 of Set 15 | cittanova
# Processing Record 33 of Set 15 | beloha
# Processing Record 34 of Set 15 | clifton
# Processing Record 35 of Set 15 | rafai
# Processing Record 36 of Set 15 | gorin
# Processing Record 37 of Set 15 | langsa
# Processing Record 38 of Set 15 | westport
# Processing Record 39 of Set 15 | marcona
# City not found. Skipping...
# Processing Record 40 of Set 15 | coracao de jesus
# Processing Record 41 of Set 15 | kahului
# Processing Record 42 of Set 15 | ossora
# Processing Record 43 of Set 15 | ugoofaaru
# Processing Record 44 of Set 15 | palompon
# Processing Record 45 of Set 15 | aden
# Processing Record 46 of Set 15 | mayor pablo lagerenza
# Processing Record 47 of Set 15 | ventanas
# Processing Record 48 of Set 15 | kant
# Processing Record 49 of Set 15 | datong
# Processing Record 50 of Set 15 | vao
# Processing Record 1 of Set 16 | ardistan
# City not found. Skipping...
# Processing Record 2 of Set 16 | kharagpur
# Processing Record 3 of Set 16 | dzilam gonzalez
# Processing Record 4 of Set 16 | alta floresta
# Processing Record 5 of Set 16 | kitimat
# Processing Record 6 of Set 16 | ayan
# Processing Record 7 of Set 16 | mongo
# Processing Record 8 of Set 16 | traverse city
# Processing Record 9 of Set 16 | biankouma
# Processing Record 10 of Set 16 | leningradskiy
# Processing Record 11 of Set 16 | roquetas de mar
# Processing Record 12 of Set 16 | sept-iles
# Processing Record 13 of Set 16 | farafangana
# Processing Record 14 of Set 16 | sarahan
# Processing Record 15 of Set 16 | sayyan
# Processing Record 16 of Set 16 | pakokku
# Processing Record 17 of Set 16 | poum
# Processing Record 18 of Set 16 | atar
# Processing Record 19 of Set 16 | dahanu
# Processing Record 20 of Set 16 | shebalino
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 713

# %%
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#                            City Country      Lat       Lng  Max Temp  \
# 0                     Busselton      AU -33.6500  115.3333     81.05
# 1                        Broome      US  42.2506  -75.8330     16.02
# 2  Presidencia Roque Saenz Pena      AR -26.7852  -60.4388     70.09
# 3                         Beira      MZ -19.8436   34.8389     75.81
# 4                  Punta Arenas      CL -53.1500  -70.9167     44.71
# 5                        Avarua      CK -21.2078 -159.7750     75.25
# 6                Ribeira Grande      PT  38.5167  -28.7000     58.08
# 7                         Lensk      RU  60.7253  114.9278    -14.46
# 8                    Lavrentiya      RU  65.5833 -171.0000    -18.63
# 9                     Jamestown      US  42.0970  -79.2353     15.12
#
#    Humidity  Cloudiness  Wind Speed Current Description
# 0        46           0        9.48           clear sky
# 1        76           0        8.05           clear sky
# 2        38           0        1.43           clear sky
# 3        85          16        3.40          few clouds
# 4        49          20        8.05          few clouds
# 5        88          20        4.61          light rain
# 6        69         100        3.51     overcast clouds
# 7        95          96        1.28     overcast clouds
# 8        93          13        2.21          few clouds
# 9        67         100        5.75     overcast clouds

# %%
output_data_file = "Weather_Database/WeatherPy_Database.csv"
city_data_df.to_csv(output_data_file, index_label='City_ID')
